# %% [markdown]
# ## 랭체인 Basic 사용법
# https://docs.langchain.com/oss/python/langchain/overview

# %% [markdown]
# - 랭체인 패키지 설치

# %%
# %pip install langchain langchain-openai

# %%
# !pip uninstall langchain langchain-core langchain-openai -y

# %%
# !pip install -U langchain langchain-core langchain-openai openai

# %%
import langchain
print(langchain.__version__)
# Out:
# 1.2.0

# %%
import sys
sys.version
# Out:
# '3.11.9 (tags/v3.11.9:de54cf5, Apr  2 2024, 10:12:12) [MSC v.1938 64 bit (AMD64)]'

# %% [markdown]
# - 환경 변수로 OpenAI API Key 읽어 오기

# %%
import os
from dotenv import load_dotenv

# .env 파일의 내용 불러오기
load_dotenv("C:/env/.env")

# 아래 코드는 생략한다

# 환경 변수 가져오기
# API_KEY = os.getenv("OPENAI_API_KEY")
# print(API_KEY)

# from openai import OpenAI
# client = OpenAI(api_key=API_KEY)

# LangChain GitHub 소스 위치 (ChatOpenAI 관련)
# https://github.com/langchain-ai/langchain/blob/master/libs/partners/openai/langchain_openai/chat_models/base.py
# Out:
# True

# %% [markdown]
# ### 랭체인 사용 OpenAI API 호출하기

# %%
from langchain_openai import ChatOpenAI
model = ChatOpenAI(model="gpt-4o-mini")
# model = ChatOpenAI(model="gpt-5-mini")
model.invoke("하늘은 왜 파란가요?")
# Out:
# AIMessage(content="하늘이 파란 이유는 주로 대기 중의 산란 현상 때문입니다. 태양광은 다양한 색깔의 빛으로 이루어져 있으며, 각각의 색깔은 다른 파장을 가지고 있습니다. \n\n햇빛이 대기에 들어오면, 파장이 짧은 파란 빛이 공기 분자와 더 많이 산란됩니다. 이 현상은 '레이리 산란'이라고 불립니다. 반면, 파장이 긴 빨간빛은 덜 산란되어 대기 중에서 상대적으로 직진합니다. 그래서 우리는 하늘을 바라볼 때 파란색이 더 많이 보이게 되는 것입니다.\n\n일몰이나 일출 때 하늘이 빨갛게 보이는 것은, 햇빛이 대기를 통과하는 거리와 관련이 있습니다. 이때는 햇빛이 더 많은 대기층을 통과해야 하므로, 파란 빛이 더 많이 산란되고 빨간색과 주황색 빛이 남게 되어 하늘이 붉게 물드는 것입니다.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 222, 'prompt_tokens': 16, 'total_tokens': 238, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b1b99e3b92', 'id': 'chatcmpl-E5SFRg2ED4IpO06UIRbrRwm5FSFd6', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f9870-6beb-7423-aa16-fa8e078e2ca0-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 16, 'output_tokens': 222, 'total_tokens': 238, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
from langchain_core.messages import HumanMessage
model.invoke([HumanMessage(content="하늘은 왜 파란가요?")])
# Out:
# AIMessage(content="하늘이 파란 이유는 주로 '레이리 산란'이라는 현상 때문입니다. 태양빛은 다양한 색의 빛으로 이루어져 있으며, 각각의 색은 서로 다른 파장을 가지고 있습니다. 이 중 파란색 빛의 파장이 짧고, 그래서 대기 중의 공기 분자에 의해 더 많이 산란됩니다.\n\n일광이 대기를 통과할 때, 파란색 빛이 다른 색보다 더 많이 산란되어 하늘이 파란색으로 보이게 됩니다. 저녁이나 이른 아침에는 태양이 수평선 근처에 위치하게 되어 빛이 대기를 더 많이 통과해야 하고, 이 과정에서 대부분의 파란색이 산란되고, 붉은색이나 오렌지색이 더욱 두드러져 보이게 됩니다. 따라서 해질녘 하늘은 주로 붉은색이나 오렌지색으로 물들게 됩니다.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 204, 'prompt_tokens': 16, 'total_tokens': 220, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b1b99e3b92', 'id': 'chatcmpl-E5SFTp4sUx2D27I5v0ComNsmZ9Pmo', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f9870-76e3-7b90-a436-514f33020f02-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 16, 'output_tokens': 204, 'total_tokens': 220, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
obj = HumanMessage(content="하늘은 왜 파란가요?")
print(type(obj))
print(obj)
# dir(obj)
# Out:
# <class 'langchain_core.messages.human.HumanMessage'>
# content='하늘은 왜 파란가요?' additional_kwargs={} response_metadata={}

# %%
model.invoke([HumanMessage(content="노란 이유는?")])  # 컨텍스트 유지 안됨
# Out:
# AIMessage(content='"노란 이유"라는 표현은 특정한 문맥이나 상황에 따라 여러 가지 의미를 가질 수 있습니다. 예를 들어, 노란색은 종종 행복, 밝음, 주의 등을 상징합니다. 특정 사물이나 상황이 노란색인 이유에 대해서 질문하신 것일 수 있습니다. 더 구체적인 상황이나 맥락을 말씀해 주시면, 보다 정확한 답변을 드릴 수 있을 것 같습니다. 어떤 내용을 궁금해하시는지 말씀해 주세요!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 108, 'prompt_tokens': 12, 'total_tokens': 120, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_73ac716e3e', 'id': 'chatcmpl-E5SFWknIaP37FmbpGbtBU2rlgHo5S', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f9870-8264-7710-b8f0-098cb99f80f3-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 12, 'output_tokens': 108, 'total_tokens': 120, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
model.invoke([HumanMessage(content="안녕? 나는 홍길동이야!")])
# Out:
# AIMessage(content='안녕하세요, 홍길동님! 만나서 반갑습니다. 어떻게 도와드릴까요?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 17, 'total_tokens': 38, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_77069cb563', 'id': 'chatcmpl-E5SFYfYz5KraMVDbyXHJKVewcJnev', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f9870-8956-7070-8e5a-a8b26a0822ba-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 17, 'output_tokens': 21, 'total_tokens': 38, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
model.invoke([HumanMessage(content="내 이름이 뭐지?")])  # 컨텍스트 유지 안됨
# Out:
# AIMessage(content='죄송하지만, 당신의 이름을 알 수 있는 정보가 없습니다. 제게 당신의 이름을 말씀해 주시면 그에 맞춰 대화할 수 있습니다!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 35, 'prompt_tokens': 13, 'total_tokens': 48, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_9899ea5f96', 'id': 'chatcmpl-E5SFZ16hM8Ifmf1mPomY8YwwouPor', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f9870-8c5b-7c82-92db-29c5804d625f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 35, 'total_tokens': 48, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
from langchain_core.messages import HumanMessage, AIMessage, SystemMessage

messages = [
    SystemMessage(content="너는 친절한 조교야."),
    HumanMessage(content="안녕?"),
    AIMessage(content="안녕하세요! 무엇을 도와드릴까요?"),
    HumanMessage(content="LangChain이 뭐야?")
]

response = model.invoke(messages)
print(response.content)
# 모델은 위 리스트를 모두 입력으로 받는다.
# 이때 모델은 시스템 지침(SystemMessage)과 이전 대화(Human/AIMessage)를 참고한다.
# 최종적으로 가장 마지막 HumanMessage(“LangChain이 뭐야?”)에 대한 응답을 생성한다.
# Out:
# LangChain은 언어 모델을 활용한 애플리케이션을 쉽게 구축할 수 있도록 도와주는 프레임워크입니다. 주로 자연어 처리(NLP)와 관련된 작업에 사용되며, 특히 대화형 AI, 챗봇, 검색 시스템 및 자동화된 콘텐츠 생성과 같은 분야에서 유용합니다.
#
# LangChain은 다음과 같은 기능을 제공합니다:
#
# 1. **체인**: 다양한 구성 요소(예: 언어 모델, 데이터베이스, API 등)를 연결하여 복잡한 작업을 수행할 수 있는 체인을 구성할 수 있습니다.
#
# 2. **프롬프트 관리**: 언어 모델에 전달되는 프롬프트를 관리하고 최적화하는 도구를 제공합니다.
#
# 3. **데이터 연동**: 외부 데이터 소스와 통합하여 입력 및 출력 작업을 더 쉽게 처리할 수 있도록 지원합니다.
#
# 4. **모듈화**: 재사용 가능한 모듈을 제공하여 애플리케이션을 보다 효율적으로 설계할 수 있게 합니다.
#
# 이 프레임워크를 사용하면 프로그래머와 데이터 과학자들이 자연어 처리 작업을 더 빠르고 쉽고 효율적으로 구현할 수 있습니다. LangChain은 오픈소스로 개발되어 있으며, 다양한 언어 모델과 함께 활용할 수 있는 유연성을 제공합니다.
#
# 더 궁금한 점이 있으면 말씀해 주세요!

# %% [markdown]
# ### 멀티턴 대화 구현하기

# %%
from langchain_openai import ChatOpenAI  
from langchain_core.messages import HumanMessage
from langchain_core.chat_history import InMemoryChatMessageHistory       # 메모리에 대화 기록을 저장하는 클래스
from langchain_core.runnables.history import RunnableWithMessageHistory  # 메시지 기록을 활용해 실행 가능한 래퍼 클래스

model = ChatOpenAI(model="gpt-4o-mini")

# 세션별 대화 기록을 저장할 딕셔너리
store = {}

# 세션 ID에 따라 대화 기록을 가져오는 함수
def get_session_history(session_id: str):
    # 만약 해당 세션 ID가 store에 없으면, 새로 생성해 추가함
    if session_id not in store:
        store[session_id] = InMemoryChatMessageHistory()  # 메모리에 대화 기록을 저장하는 객체 생성
    return store[session_id]                              # 해당 세션의 대화 기록을 반환

# 모델 실행 시 대화 기록을 함께 전달하는 래퍼 객체 생성
with_message_history = RunnableWithMessageHistory(model, get_session_history)

# %%
print(type(with_message_history))
print(with_message_history)
# Out:
# <class 'langchain_core.runnables.history.RunnableWithMessageHistory'>
# bound=RunnableBinding(bound=RunnableBinding(bound=RunnableLambda(_enter_history), kwargs={}, config={'run_name': 'load_history'}, config_factories=[])
# | RunnableBinding(bound=RunnableLambda(_call_runnable_sync), kwargs={}, config={'run_name': 'check_sync_or_async'}, config_factories=[]), kwargs={}, config={'run_name': 'RunnableWithMessageHistory'}, config_factories=[]) kwargs={} config={} config_factories=[] get_session_history=<function get_session_history at 0x000001F4617F5F80> history_factory_config=[ConfigurableFieldSpec(id='session_id', annotation=<class 'str'>, name='Session ID', description='Unique identifier for a session.', default='', is_shared=True, dependencies=None)]

# %%
config = {"configurable": {"session_id": "chat-001"}}  # 세션 ID를 설정하는 config 객체 생성

response = with_message_history.invoke(
    [HumanMessage(content="안녕? 나는 홍길동이야!")],
    # [HumanMessage(content="안녕? 나는 Smith야!")],
    config=config,
)

print(response.content)
# Out:
# 안녕하세요, 홍길동님! 만나서 반갑습니다. 어떻게 도와드릴까요?

# %%
config
# Out:
# {'configurable': {'session_id': 'chat-001'}}

# %%
response = with_message_history.invoke(
    [HumanMessage(content="내 이름이 뭐지?")],
    config=config,
)

print(response.content)
# Out:
# 홍길동님이라고 하셨습니다! 맞나요?

# %%
config = {"configurable": {"session_id": "chat-002"}}

response = with_message_history.invoke(
    [HumanMessage(content="내 이름이 뭐지?")],
    config=config,
)

print(response.content)
# Out:
# 죄송하지만, 저는 당신의 이름을 알 수 없습니다. 이름이나 다른 개인 정보를 제공해 주시면 그에 맞춰 대화할 수 있습니다. 어떻게 도와드릴까요?

# %%
config = {"configurable": {"session_id": "chat-001"}}

response = with_message_history.invoke(
    [HumanMessage(content="아까 우리가 무슨 얘기 했지?")],
    config=config,
)

print(response.content)
# Out:
# 우리는 당신의 이름에 대해 이야기를 나누었고, 당신은 홍길동이라고 소개하셨습니다. 더 이야기하고 싶은 주제가 있나요?

# %% [markdown]
# ### 스트림 방식으로 출력하기

# %%
config = {"configurable": {"session_id": "chat-001"}}
for r in with_message_history.stream(
    [HumanMessage(content = "내가 어느 나라 사람인지 맞춰보고, 그 나라의 전통 문화에 대해 말해봐")],
    config=config,
):
    print(r.content, end="|")
# Out:
# |홍|길|동|이라는| 이름|은| 한국|에서| 유|래|된| 유명|한| 전|설|적인| 인|물|의| 이름|입니다|.| 따라서| 한국| 분|이지| 않을|까| 추|측|해|봅니다|.
#
# |한국|의| 전|통| 문화| 중| 하나|로|는| 한|복|이| 있습니다|.| 한|복|은| 한국|의| 전|통| 의|복|으로|,| 보|통| 특별|한| 날|이나| 명|절|에| 입|습니다|.| 한|복|은| 색|상|과| 디자인|이| 다양|하며|,| 주|로| 자연|에서| 영|감을| 받은| 색|채|가| 많이| 사용|됩니다|.| 전|통| 명|절|인| 설|날|이나| 추|석| 같은| 날|에| 한|복|을| 입|고| 가족|과| 함께| 시간을| 보내|는| 것이| 일반|적|입니다|.
#
# |또| 다른| 전|통| 문화|로|는| 차|례|가| 있습니다|.| 차|례|는| 조|상|에게| 감사|의| 뜻|을| 전|하기| 위해| 음|식을| 차|려|놓|고| 제|를| 지|내|는| 의|식|입니다|.| 보|통| 추|석|과| 설|날|에| 해당|됩니다|.
#
# |더| 궁|금|한| 한국|의| 전|통| 문화|가| 있|으면| 말씀|해| 주세요|!||||
