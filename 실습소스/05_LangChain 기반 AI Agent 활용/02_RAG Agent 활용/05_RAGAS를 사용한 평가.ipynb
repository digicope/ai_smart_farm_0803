# %% [markdown]
# ## RAGRAS를 사용한 평가

# %%
import os
from dotenv import load_dotenv

# .env 파일의 내용 불러오기
load_dotenv("C:/env/.env")
# Out:
# True

# %% [markdown]
# ### RAGAS (Retrieval-Augmented Generation Assessment Suite)
# RAGAS는 RAG(Retrieval-Augmented Generation) 시스템의 응답 품질을 자동으로 평가하기 위한 프레임워크이다.

# %%
# ! pip install ragas evaluate datasets

# %%
# [환경 호환성 패치] 이 환경에 설치된 langchain-community(0.4.x)는
# langchain 1.x 계열로 넘어오면서 langchain_community.chat_models.vertexai
# 서브모듈(ChatVertexAI)을 제거했다. 하지만 ragas==0.2.10은 여전히 이 경로를
# 무조건 import하도록 작성되어 있어 `from ragas import evaluate` 시점에
# ModuleNotFoundError가 발생한다.
#
# 이 노트북은 Vertex AI를 전혀 사용하지 않으므로(OpenAI만 사용), 실제
# langchain-community를 다운그레이드하는 대신 ragas가 import할 수 있도록
# 최소한의 더미(stub) 모듈을 sys.modules에 등록해 import 오류만 회피한다.
import sys
import types

if "langchain_community.chat_models.vertexai" not in sys.modules:
    stub = types.ModuleType("langchain_community.chat_models.vertexai")

    class ChatVertexAI:  # pragma: no cover - 사용되지 않는 더미 클래스
        def __init__(self, *args, **kwargs):
            raise RuntimeError(
                "이 노트북은 OpenAI만 사용하도록 구성되어 있어 "
                "ChatVertexAI는 실제로 지원되지 않습니다."
            )

    stub.ChatVertexAI = ChatVertexAI
    sys.modules["langchain_community.chat_models.vertexai"] = stub

print("langchain_community.chat_models.vertexai 호환성 패치 적용 완료")
# Out:
# langchain_community.chat_models.vertexai 호환성 패치 적용 완료

# %%
import os
os.environ["GIT_PYTHON_REFRESH"] = "quiet"

import ragas
print(ragas.__version__)
# Out:
# 0.2.10

# %%
from datasets import Dataset
from ragas import evaluate
from ragas.metrics import (
    ContextPrecision,
    ContextRecall,
    Faithfulness,
    ResponseRelevancy
)

# 데이터 준비
data = {
    "question": ["딥러닝이란 무엇인가?"],
    "contexts": [["딥러닝은 인공신경망을 사용하는 머신러닝의 한 분야이다."]],
    "answer": ["딥러닝은 머신러닝의 하위 분야로 신경망을 사용한다."],
    "ground_truth": ["딥러닝은 인공신경망을 기반으로 한 머신러닝 기술이다."]
}
dataset = Dataset.from_dict(data)

# 메트릭 객체 인스턴스 생성
metrics = [
    Faithfulness(),
    ResponseRelevancy(),
    ContextPrecision(),
    ContextRecall()
]

# 평가 실행
results = evaluate(dataset=dataset, metrics=metrics)
print(results)
# Out:
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
# {'faithfulness': 1.0000, 'answer_relevancy': 0.8375, 'context_precision': 1.0000, 'context_recall': 1.0000}

# %% [markdown]
# ### RAG + RAGAS 평가 자동화 에이전트 구현

# %%
# ==============================================================
# 복합 RAG + RAGAS 평가 자동화 에이전트 예제 (LangChain v1.0 + RAGAS 0.3.7)
# ==============================================================

# 설치 필요:
# pip install langchain langchain-openai langchain-chroma ragas evaluate datasets pandas

import os
from dotenv import load_dotenv
import pandas as pd
from typing import List, Dict

from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_chroma import Chroma
from langchain_core.documents import Document
from langchain.agents import create_agent
from langchain.tools import tool

from datasets import Dataset
from ragas import evaluate
from ragas.metrics import (
    Faithfulness,
    ResponseRelevancy,
    ContextPrecision,
    ContextRecall
)

# --------------------------------------------------------------
# 1. 환경 설정
# --------------------------------------------------------------
# load_dotenv()
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)
embedding = OpenAIEmbeddings(model="text-embedding-3-small")

# --------------------------------------------------------------
# 2. 예시 문서 데이터
# --------------------------------------------------------------
docs = [
    Document(page_content="인공지능은 인간의 지능을 모방하는 기술이며, 다양한 분야에서 활용된다."),
    Document(page_content="머신러닝은 데이터를 이용해 학습하는 AI의 한 영역이다."),
    Document(page_content="딥러닝은 인공신경망 기반의 머신러닝 기법으로 이미지, 음성 인식에 뛰어나다."),
    Document(page_content="자연어처리는 인간의 언어를 이해하고 생성하는 AI 기술이다."),
    Document(page_content="강화학습은 보상 기반으로 학습하여 행동을 최적화하는 AI 분야이다.")
]

# --------------------------------------------------------------
# 3. 벡터스토어 생성
# --------------------------------------------------------------
db = Chroma.from_documents(docs, embedding)

# --------------------------------------------------------------
# 4. 검색 Tool 정의
# --------------------------------------------------------------
@tool
def semantic_retrieve(query: str) -> str:
    """주어진 질문과 관련된 문서를 검색하여 반환한다."""
    retriever = db.as_retriever(search_kwargs={"k": 3})
    results = retriever.invoke(query)
    return "\n".join([r.page_content for r in results])

# --------------------------------------------------------------
# 5. 에이전트 생성
# --------------------------------------------------------------
rag_agent = create_agent(
    model=llm,
    tools=[semantic_retrieve],
    system_prompt=(
        "당신은 검색과 문서 요약을 수행하는 RAG 분석 에이전트이다. "
        "주어진 질문에 대해 관련 문서를 검색하고, 근거를 바탕으로 신뢰성 있는 답변을 생성하라. "
        "모르면 추측하지 말고 '관련 정보가 없습니다.'라고 답하라."
    )
)

# --------------------------------------------------------------
# 6. 다중 질의 실행 및 결과 저장
# --------------------------------------------------------------
questions = [
    "딥러닝이란 무엇인가?",
    "자연어처리는 어떤 기술인가?",
    "강화학습은 어떤 원리로 동작하는가?",
    "머신러닝과 딥러닝의 차이점을 설명해줘.",
    "AI는 인간의 사고를 완전히 대체할 수 있는가?"
]

answers, contexts = [], []

for q in questions:
    result = rag_agent.invoke({"messages": [{"role": "user", "content": q}]})
    answer = result["messages"][-1].content
    print(f"[질문] {q}\n[답변] {answer}\n{'-'*60}")
    answers.append(answer)
    contexts.append([doc.page_content for doc in docs])

# --------------------------------------------------------------
# 7. 평가용 데이터셋 구성
# --------------------------------------------------------------
data = {
    "question": questions,
    "contexts": contexts,
    "answer": answers,
    "ground_truth": [
        "딥러닝은 인공신경망을 사용하는 머신러닝의 하위 분야이다.",
        "자연어처리는 인간의 언어를 이해하고 생성하는 인공지능 기술이다.",
        "강화학습은 보상 기반으로 학습하여 최적의 행동을 선택하는 방법이다.",
        "딥러닝은 머신러닝의 일부로, 신경망을 사용한다.",
        "AI는 인간 사고를 완전히 대체하기 어렵다."
    ]
}

dataset = Dataset.from_dict(data)

# --------------------------------------------------------------
# 8. RAGAS 평가 수행
# --------------------------------------------------------------
metrics = [
    Faithfulness(),
    ResponseRelevancy(),
    ContextPrecision(),
    ContextRecall()
]

print("\n[🔍 RAGAS 평가 시작]")
results = evaluate(dataset=dataset, metrics=metrics)

# --------------------------------------------------------------
# 9. 평가 결과 출력
# --------------------------------------------------------------
print("\n=== RAGAS 평가 결과 ===")
print(results)

# DataFrame 형태로 보기 좋게 표시
df_results = pd.DataFrame([results])
print("\n평가 점수표:\n", df_results)
# Out:
# [질문] 딥러닝이란 무엇인가?
# [답변] 딥러닝은 인공신경망 기반의 머신러닝 기법으로, 주로 이미지 및 음성 인식 분야에서 뛰어난 성능을 발휘합니다. 이는 머신러닝의 한 영역으로, 데이터를 이용해 학습하는 방식입니다.
# ------------------------------------------------------------
# [질문] 자연어처리는 어떤 기술인가?
# [답변] 자연어처리(Natural Language Processing, NLP)는 인간의 언어를 이해하고 생성하는 인공지능(AI) 기술입니다. 이 기술은 컴퓨터가 인간의 언어를 해석하고, 의미를 파악하며, 자연스러운 언어로 응답할 수 있도록 돕습니다.
# ------------------------------------------------------------
# [질문] 강화학습은 어떤 원리로 동작하는가?
# [답변] 강화학습은 보상 기반으로 학습하여 행동을 최적화하는 인공지능(AI) 분야입니다. 에이전트는 환경과 상호작용하며, 특정 행동을 취했을 때 받는 보상을 통해 학습합니다. 이 과정을 통해 에이전트는 장기적인 보상을 극대화하는 방향으로 행동을 조정하게 됩니다.
# ------------------------------------------------------------
# [질문] 머신러닝과 딥러닝의 차이점을 설명해줘.
# [답변] 머신러닝과 딥러닝의 차이점은 다음과 같습니다:
#
# 1. **정의**:
#    - **머신러닝**: 데이터를 이용해 학습하는 인공지능(AI)의 한 영역으로, 다양한 알고리즘을 사용하여 패턴을 인식하고 예측을 수행합니다.
#    - **딥러닝**: 머신러닝의 한 하위 분야로, 인공신경망을 기반으로 하여 복잡한 데이터의 패턴을 학습하는 기법입니다.
#
# 2. **구조**:
#    - 머신러닝은 다양한 알고리즘(예: 결정 트리, 서포트 벡터 머신 등)을 사용하여 데이터를 분석합니다.
#    - 딥러닝은 여러 층의 인공신경망을 사용하여 데이터의 특징을 자동으로 추출하고 학습합니다.
#
# 3. **적용 분야**:
#    - 머신러닝은 일반적으로 구조화된 데이터에 잘 작동하며, 예측, 분류, 클러스터링 등의 작업에 사용됩니다.
#    - 딥러닝은 이미지 인식, 음성 인식 등 비구조화된 데이터에 특히 뛰어난 성능을 보입니다.
#
# 딥러닝은 머신러닝의 한 형태로, 더 복잡한 문제를 해결하는 데 강력한 도구입니다.
# ------------------------------------------------------------
# [질문] AI는 인간의 사고를 완전히 대체할 수 있는가?
# [답변] 현재의 인공지능(AI)은 인간의 사고를 완전히 대체할 수 없습니다. AI는 인간의 지능을 모방하는 기술로, 특정 작업이나 문제 해결에 있어 인간보다 더 효율적일 수 있지만, 인간의 복잡한 사고 과정, 감정, 창의성 등을 완전히 재현하거나 대체하는 것은 불가능합니다. AI는 특정 분야에서 유용하게 활용되지만, 인간의 사고를 전면적으로 대체할 수 있는 수준에는 이르지 못하고 있습니다.
# ------------------------------------------------------------
#
# [🔍 RAGAS 평가 시작]
# Evaluating:   0%|          | 0/20 [00:00<?, ?it/s]
# === RAGAS 평가 결과 ===
# {'faithfulness': 0.5922, 'answer_relevancy': 0.8171, 'context_precision': 0.2233, 'context_recall': 0.8000}
#
# 평가 점수표:
#                                                scores  \
# 0  [{'faithfulness': 0.75, 'answer_relevancy': 0....
#
#                                              dataset binary_columns cost_cb  \
# 0  {'samples': [user_input='딥러닝이란 무엇인가?' retrieve...             []    None
#
#                                               traces  \
# 0  [{'scores': {'faithfulness': 0.75, 'answer_rel...
#
#                                         ragas_traces run_id
# 0  {'01a0575e-23ed-7490-b145-eed34cbcf5d5': run_i...   None

# %%
df_results
# Out:
#                                               scores  \
# 0  [{'faithfulness': 0.75, 'answer_relevancy': 0....
#
#                                              dataset binary_columns cost_cb  \
# 0  {'samples': [user_input='딥러닝이란 무엇인가?' retrieve...             []    None
#
#                                               traces  \
# 0  [{'scores': {'faithfulness': 0.75, 'answer_rel...
#
#                                         ragas_traces run_id
# 0  {'01a0575e-23ed-7490-b145-eed34cbcf5d5': run_i...   None

# %%
# 질문별 상세 평가 결과
# 평가 결과를 DataFrame으로 변환
df = results.to_pandas()
df
# Out:
#                    user_input  \
# 0                 딥러닝이란 무엇인가?
# 1             자연어처리는 어떤 기술인가?
# 2         강화학습은 어떤 원리로 동작하는가?
# 3       머신러닝과 딥러닝의 차이점을 설명해줘.
# 4  AI는 인간의 사고를 완전히 대체할 수 있는가?
#
#                                   retrieved_contexts  \
# 0  [인공지능은 인간의 지능을 모방하는 기술이며, 다양한 분야에서 활용된다., 머신러닝...
# 1  [인공지능은 인간의 지능을 모방하는 기술이며, 다양한 분야에서 활용된다., 머신러닝...
# 2  [인공지능은 인간의 지능을 모방하는 기술이며, 다양한 분야에서 활용된다., 머신러닝...
# 3  [인공지능은 인간의 지능을 모방하는 기술이며, 다양한 분야에서 활용된다., 머신러닝...
# 4  [인공지능은 인간의 지능을 모방하는 기술이며, 다양한 분야에서 활용된다., 머신러닝...
#
#                                             response  \
# 0  딥러닝은 인공신경망 기반의 머신러닝 기법으로, 주로 이미지 및 음성 인식 분야에서 ...
# 1  자연어처리(Natural Language Processing, NLP)는 인간의 언...
# 2  강화학습은 보상 기반으로 학습하여 행동을 최적화하는 인공지능(AI) 분야입니다. 에...
# 3  머신러닝과 딥러닝의 차이점은 다음과 같습니다:\n\n1. **정의**:\n   - ...
# 4  현재의 인공지능(AI)은 인간의 사고를 완전히 대체할 수 없습니다. AI는 인간의 ...
#
#                                reference  faithfulness  answer_relevancy  \
# 0        딥러닝은 인공신경망을 사용하는 머신러닝의 하위 분야이다.      0.750000          0.822141
# 1    자연어처리는 인간의 언어를 이해하고 생성하는 인공지능 기술이다.      0.800000          0.805946
# 2  강화학습은 보상 기반으로 학습하여 최적의 행동을 선택하는 방법이다.      0.800000          0.770337
# 3             딥러닝은 머신러닝의 일부로, 신경망을 사용한다.      0.277778          0.844088
# 4               AI는 인간 사고를 완전히 대체하기 어렵다.      0.333333          0.842958
#
#    context_precision  context_recall
# 0           0.333333             1.0
# 1           0.250000             1.0
# 2           0.200000             1.0
# 3           0.333333             1.0
# 4           0.000000             0.0
